# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sma
from scipy import stats 

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ## Import the dataset

# %%
data = pd.read_excel('Concrete_Data.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   ccs                 1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
data.describe().T
# Out:
#                      count        mean         std         min         25%  \
# Cement              1030.0  281.165631  104.507142  102.000000  192.375000
# Blast Furnace Slag  1030.0   73.895485   86.279104    0.000000    0.000000
# Fly Ash             1030.0   54.187136   63.996469    0.000000    0.000000
# Water               1030.0  181.566359   21.355567  121.750000  164.900000
# Superplasticizer    1030.0    6.203112    5.973492    0.000000    0.000000
# Coarse Aggregate    1030.0  972.918592   77.753818  801.000000  932.000000
# Fine Aggregate      1030.0  773.578883   80.175427  594.000000  730.950000
# Age                 1030.0   45.662136   63.169912    1.000000    7.000000
# ccs                 1030.0   35.817836   16.705679    2.331808   23.707115
#
#                            50%          75%          max
# Cement              272.900000   350.000000   540.000000
# Blast Furnace Slag   22.000000   142.950000   359.400000
# Fly Ash               0.000000   118.270000   200.100000
# Water               185.000000   192.000000   247.000000
# Superplasticizer      6.350000    10.160000    32.200000
# Coarse Aggregate    968.000000  1029.400000  1145.000000
# Fine Aggregate      779.510000   824.000000   992.600000
# Age                  28.000000    56.000000   365.000000
# ccs                  34.442774    46.136287    82.599225

# %%
# Correlation Plot
sns.heatmap(data.corr(),annot=True,vmax=1,vmin=-1,cmap='RdBu',
            mask=np.triu(data.corr()))
plt.show()

# %% [markdown]
# ## Treat the defects

# %%
# Missing Values
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# ccs                   0
# dtype: int64

# %%
# Duplicates
data[data.duplicated()]
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 77    425.0               106.3      0.0  153.5              16.5
# 80    425.0               106.3      0.0  153.5              16.5
# 86    362.6               189.0      0.0  164.9              11.6
# 88    362.6               189.0      0.0  164.9              11.6
# 91    362.6               189.0      0.0  164.9              11.6
# 100   425.0               106.3      0.0  153.5              16.5
# 103   425.0               106.3      0.0  153.5              16.5
# 109   362.6               189.0      0.0  164.9              11.6
# 111   362.6               189.0      0.0  164.9              11.6
# 123   425.0               106.3      0.0  153.5              16.5
# 126   425.0               106.3      0.0  153.5              16.5
# 132   362.6               189.0      0.0  164.9              11.6
# 134   362.6               189.0      0.0  164.9              11.6
# 137   362.6               189.0      0.0  164.9              11.6
# 146   425.0               106.3      0.0  153.5              16.5
# 149   425.0               106.3      0.0  153.5              16.5
# 155   362.6               189.0      0.0  164.9              11.6
# 157   362.6               189.0      0.0  164.9              11.6
# 160   362.6               189.0      0.0  164.9              11.6
# 169   425.0               106.3      0.0  153.5              16.5
# 172   425.0               106.3      0.0  153.5              16.5
# 177   362.6               189.0      0.0  164.9              11.6
# 179   362.6               189.0      0.0  164.9              11.6
# 182   362.6               189.0      0.0  164.9              11.6
# 809   252.0                 0.0      0.0  185.0               0.0
#
#      Coarse Aggregate  Fine Aggregate  Age        ccs
# 77              852.1           887.1    3  33.398217
# 80              852.1           887.1    3  33.398217
# 86              944.7           755.8    3  35.301171
# 88              944.7           755.8    3  35.301171
# 91              944.7           755.8    3  35.301171
# 100             852.1           887.1    7  49.201007
# 103             852.1           887.1    7  49.201007
# 109             944.7           755.8    7  55.895819
# 111             944.7           755.8    7  55.895819
# 123             852.1           887.1   28  60.294676
# 126             852.1           887.1   28  60.294676
# 132             944.7           755.8   28  71.298713
# 134             944.7           755.8   28  71.298713
# 137             944.7           755.8   28  71.298713
# 146             852.1           887.1   56  64.300532
# 149             852.1           887.1   56  64.300532
# 155             944.7           755.8   56  77.297154
# 157             944.7           755.8   56  77.297154
# 160             944.7           755.8   56  77.297154
# 169             852.1           887.1   91  65.196851
# 172             852.1           887.1   91  65.196851
# 177             944.7           755.8   91  79.296635
# 179             944.7           755.8   91  79.296635
# 182             944.7           755.8   91  79.296635
# 809            1111.0           784.0   28  19.691435

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1005, 9)

# %%
# Check for the outliers
t=1
plt.figure(figsize=(10,17))
for i in data.columns:
    plt.subplot(5,2,t)
    sns.boxplot(x=data[i])
    t+=1
plt.tight_layout()
plt.show()

# %%
# Cappping
for i in data.columns:
    q3,q1 = np.percentile(data[i],[75,25])
    iqr = q3-q1
    ul,ll = q3+1.5*iqr, q1-1.5*iqr
    data[i] = data[i].apply(lambda x: ul if x>ul else ll if x<ll else x)

# %%
t=1
plt.figure(figsize=(10,17))
for i in data.columns:
    plt.subplot(5,2,t)
    sns.boxplot(x=data[i])
    t+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression Analysis

# %%
# lets split x and y
y=data['ccs']
x=data.drop(columns='ccs')

# %%
# add a constant in x to have an intercept in a model
x_c=sma.add_constant(x)

# %%
sma.OLS(y,x_c).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ccs   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.719
# Method:                 Least Squares   F-statistic:                     322.7
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):          2.10e-270
# Time:                        12:36:21   Log-Likelihood:                -3583.1
# No. Observations:                1005   AIC:                             7184.
# Df Residuals:                     996   BIC:                             7228.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  3.9349     22.392      0.176      0.861     -40.006      47.876
# Cement                 0.1109      0.007     15.544      0.000       0.097       0.125
# Blast Furnace Slag     0.0920      0.008     10.829      0.000       0.075       0.109
# Fly Ash                0.0737      0.010      7.080      0.000       0.053       0.094
# Water                 -0.1826      0.034     -5.337      0.000      -0.250      -0.115
# Superplasticizer       0.2468      0.083      2.986      0.003       0.085       0.409
# Coarse Aggregate       0.0060      0.008      0.766      0.444      -0.009       0.021
# Fine Aggregate         0.0079      0.009      0.876      0.381      -0.010       0.026
# Age                    0.2498      0.008     32.126      0.000       0.235       0.265
# ==============================================================================
# Omnibus:                        5.538   Durbin-Watson:                   1.266
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                6.047
# Skew:                           0.107   Prob(JB):                       0.0486
# Kurtosis:                       3.314   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# assumption 2 : Multicolinearity

# %%
# high condition no. suggest there is multi colinearity in the model

# in order to find which columns have multicolinearity lets find VIF

vif=[]
for i in range(x.shape[1]):
    vif.append(variance_inflation_factor(x.values,i))
pd.DataFrame({'VIF':vif},index=x.columns).sort_values(by='VIF',ascending=False)
# Out:
#                           VIF
# Coarse Aggregate    85.016957
# Water               82.028328
# Fine Aggregate      72.308018
# Cement              15.213900
# Superplasticizer     5.513072
# Fly Ash              4.325332
# Blast Furnace Slag   3.307520
# Age                  2.250063

# %%
sma.OLS(y,x_c.drop(columns='Coarse Aggregate')).fit().rsquared
# Out:
# 0.7214599162155249

# %%
# lets drop Coarse Aggregate and check VIF
x_c.drop(columns='Coarse Aggregate',inplace=True)
x.drop(columns='Coarse Aggregate',inplace=True)

vif=[]
for i in range(x.shape[1]):
    vif.append(variance_inflation_factor(x.values,i))
pd.DataFrame({'VIF':vif},index=x.columns).sort_values(by='VIF',ascending=False)
# Out:
#                           VIF
# Water               72.333537
# Fine Aggregate      47.949524
# Cement              14.267535
# Superplasticizer     5.464804
# Fly Ash              4.159872
# Blast Furnace Slag   3.278204
# Age                  2.248795

# %%
sma.OLS(y,x_c.drop(columns='Fine Aggregate')).fit().rsquared
# Out:
# 0.7214079179608108

# %%
# lets drop Coarse Aggregate and check VIF
x_c.drop(columns='Fine Aggregate',inplace=True)
x.drop(columns='Fine Aggregate',inplace=True)

vif=[]
for i in range(x.shape[1]):
    vif.append(variance_inflation_factor(x.values,i))
pd.DataFrame({'VIF':vif},index=x.columns).sort_values(by='VIF',ascending=False)
# Out:
#                           VIF
# Water               21.626638
# Cement              13.954376
# Fly Ash              4.068454
# Superplasticizer     3.918141
# Blast Furnace Slag   2.991824
# Age                  2.234706

# %%
# lets apply feature engineering so we keep both cement and water 
# water in model to cement ratio

x['water_cement_ratio']=x['Water']/x['Cement']
x_c['water_cement_ratio']=x_c['Water']/x_c['Cement']

x.drop(columns=['Water','Cement'],inplace=True)
x_c.drop(columns=['Water','Cement'],inplace=True)

vif=[]
for i in range(x.shape[1]):
    vif.append(variance_inflation_factor(x.values,i))
pd.DataFrame({'VIF':vif},index=x.columns).sort_values(by='VIF',ascending=False)
# Out:
#                          VIF
# water_cement_ratio  5.594984
# Fly Ash             3.563203
# Blast Furnace Slag  2.973004
# Superplasticizer    2.544618
# Age                 1.864683

# %%
sma.OLS(y,x_c).fit().rsquared
# Out:
# 0.6653811107483301

# %%
# lets fit the model over here 
# model with intercept
model=sma.OLS(y,x_c).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ccs   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     397.3
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):          1.49e-234
# Time:                        12:36:21   Log-Likelihood:                -3675.6
# No. Observations:                1005   AIC:                             7363.
# Df Residuals:                     999   BIC:                             7393.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 39.5962      1.013     39.086      0.000      37.608      41.584
# Blast Furnace Slag     0.0798      0.005     17.208      0.000       0.071       0.089
# Fly Ash                0.0396      0.007      5.841      0.000       0.026       0.053
# Superplasticizer       0.6002      0.068      8.862      0.000       0.467       0.733
# Age                    0.2369      0.008     28.279      0.000       0.220       0.253
# water_cement_ratio   -32.9598      1.296    -25.432      0.000     -35.503     -30.417
# ==============================================================================
# Omnibus:                       49.960   Durbin-Watson:                   1.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.364
# Skew:                           0.441   Prob(JB):                     5.26e-16
# Kurtosis:                       3.951   Cond. No.                         623.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# feature improtances
model.pvalues.sort_values()
# Out:
# const                 1.644812e-203
# Age                   1.019237e-129
# water_cement_ratio    2.023594e-110
# Blast Furnace Slag     2.551503e-58
# Superplasticizer       3.541361e-18
# Fly Ash                7.008803e-09
# dtype: float64

# %% [markdown]
# assumption 3 : linearity

# %%
for i in x.columns:
    plt.scatter(y=model.resid,x=x[i])
    plt.title(i)
    plt.show()

# %%
# rainbow test
from statsmodels.stats.diagnostic import linear_rainbow

# ho: linear relation b/w independent var and target variable 
# ha: non linear relation b/w independent var and target variable 

linear_rainbow(model)
(teststats,pvalue)=linear_rainbow(model)
print(f'teststats : {teststats} , pvalue {pvalue}')

if pvalue>0.05:
    print('fail to reject ho')
else:
    print('reject ho')
# Out:
# teststats : 0.9376282953485992 , pvalue 0.7640822761645768
# fail to reject ho

# %% [markdown]
# assumption 4 : auto correlation

# %% [markdown]
# - d=1.221
# - so we can conclude that there is +ve correlation. there is also a chance that this value because of small sample size

# %% [markdown]
# assumption 5 : homoscadaticity

# %%
# residual plot

sns.residplot(x=model.fittedvalues,y=model.resid)
plt.show()

# %%
# bruech pagan test 

# ho: there is homoscadascity
# ha: there is no homoscadascity

pval=sma.stats.diagnostic.het_breuschpagan(exog_het=x_c.values,resid=model.resid)[1]

if pval>0.05:
    print('fail to reject ho')
else:
    print('reject ho')
# Out:
# reject ho

# %% [markdown]
# assumption 6 : residual normality

# %%
model.resid
stats.probplot(model.resid,plot=plt)
plt.show()

# %%
# Shapiro (n<5000)
# ho: data is normal
# ha: data is not normal

stats.shapiro(model.resid)
# reject ho as p_val<alpha
pvalue=stats.shapiro(model.resid)[1]
if pvalue>0.05:
    print('fail to reject ho')
else:
    print('reject ho')
# Out:
# reject ho

# %% [raw]
# summarize the assumptions :
#
# - assumption 1 : target must be numeric : not voilated
# - assumption 2 : Multicolinearity       : not voilated
# - assumption 3 : linearity              : not voilated
# - assumption 4 : auto correlation       : not voilated
# - assumption 5 : homoscadaticity        : voilated
# - assumption 6 : residual normality     : voilated

# %% [markdown]
# ## Bussiness Interpretation

# %%
# significant columns

model.pvalues.sort_values()
# Out:
# const                 1.644812e-203
# Age                   1.019237e-129
# water_cement_ratio    2.023594e-110
# Blast Furnace Slag     2.551503e-58
# Superplasticizer       3.541361e-18
# Fly Ash                7.008803e-09
# dtype: float64

# %%
# Effect of independent variables on ccs

model.conf_int()
# Out:
#                             0          1
# const               37.608241  41.584138
# Blast Furnace Slag   0.070708   0.088910
# Fly Ash              0.026271   0.052853
# Superplasticizer     0.467261   0.733054
# Age                  0.220434   0.253308
# water_cement_ratio -35.502908 -30.416609

# %% [markdown]
# ## Predictive Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,mean_absolute_percentage_error,mean_absolute_error

# %%
y=data['ccs']
x=data.drop(columns='ccs')

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(standardize=False)

# %%
x_t=pd.DataFrame(pt.fit_transform(x_c))
x_t.head()
# Out:
#      0         1    2        3         4         5
# 0  1.0 -0.000000 -0.0  1.47685  4.366964  0.221826
# 1  1.0 -0.000000 -0.0  1.47685  4.366964  0.221826
# 2  1.0  4.896472 -0.0  0.00000  7.142743  0.377556
# 3  1.0  4.896472 -0.0  0.00000  7.142743  0.377556
# 4  1.0  4.825518 -0.0  0.00000  7.142743  0.447698

# %%
# train-test split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (804, 8) (201, 8) (804,) (201,)

# %%
# base model

model_lr=LinearRegression()

model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model_lr.intercept_
# Out:
# -8.102624717950853

# %%
model_lr.coef_
# Out:
# array([ 0.11408885,  0.09772627,  0.08242726, -0.1917599 ,  0.17141977,
#         0.01168966,  0.01659225,  0.25023773])

# %%
y_pred=model_lr.predict(x_test)

# %%
print('r2 score : ',r2_score(y_test,y_pred))
print('MSE : ',mean_squared_error(y_test,y_pred))
print('RMSE : ',(mean_squared_error(y_test,y_pred))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# r2 score :  0.7179665342052456
# MSE :  73.66535812030423
# RMSE :  8.582852563122836
# MAE :  6.690355643332342
# MAPE :  0.253258830067976

# %%
# for example if we use decision tree regressor

from sklearn.tree import DecisionTreeRegressor

model_dt=DecisionTreeRegressor(max_depth=5)

model_dt.fit(x_train,y_train)

y_pred_dt=model_dt.predict(x_test)

print('r2 score : ',r2_score(y_test,y_pred_dt))
print('MSE : ',mean_squared_error(y_test,y_pred_dt))
print('RMSE : ',(mean_squared_error(y_test,y_pred_dt))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred_dt))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred_dt))
# Out:
# r2 score :  0.7704397336727098
# MSE :  59.959690179103475
# RMSE :  7.743364267494037
# MAE :  6.095388766861035
# MAPE :  0.24363547461456264

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
from xgboost import XGBRegressor

model_xgb=XGBRegressor()

model_xgb.fit(x_train,y_train)

y_pred_xgb=model_xgb.predict(x_test)

print('r2 score : ',r2_score(y_test,y_pred_xgb))
print('MSE : ',mean_squared_error(y_test,y_pred_xgb))
print('RMSE : ',(mean_squared_error(y_test,y_pred_xgb))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred_xgb))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred_xgb))
# Out:
# r2 score :  0.9358787486787365
# MSE :  16.74806544107206
# RMSE :  4.092440035122331
# MAE :  2.8562138449198464
# MAPE :  0.1053511763135944

# %%
# lets suppose we have tunned and ot XGB as generalised model. it can be deployed
c,bfs,fly,water,sup,ca,fa,age=450,100,0,130,2,900,550,30

# %%
model_xgb.predict([[c,bfs,fly,water,sup,ca,fa,age]])
# Out:
# array([55.859013], dtype=float32)

# %%
model_lr.predict([[c,bfs,fly,water,sup,ca,fa,age]])
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([55.577596])

# %%
model_dt.predict([[c,bfs,fly,water,sup,ca,fa,age]])
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([65.87411084])

# %%
y_test.head(3)
# Out:
# 734    40.658400
# 690    23.523542
# 322    42.030457
# Name: ccs, dtype: float64

# %%
y_pred_dt[:3]
# Out:
# array([31.7922467 , 20.36529128, 42.48540277])

# %%
y_pred[:3]
# Out:
# array([43.18528388, 31.25684596, 40.64217626])

# %%
y_pred_xgb[:3]
# Out:
# array([37.559772, 22.271505, 43.14089 ], dtype=float32)

# %% [markdown]
# ### Bias and Variance

# %%
# l.r 

# train scores and errors
y_pred_1=model_lr.predict(x_train)
print('r2 score train : ',r2_score(y_train,y_pred_1))
print('MSE : ',mean_squared_error(y_train,y_pred_1))
print('RMSE : ',(mean_squared_error(y_train,y_pred_1))**0.5)
print('MAE : ',mean_absolute_error(y_train,y_pred_1))
print('MAPE : ',mean_absolute_percentage_error(y_train,y_pred_1))

# test scores and errors
y_pred=model_lr.predict(x_test)
print('\nr2 score test : ',r2_score(y_test,y_pred))
print('MSE : ',mean_squared_error(y_test,y_pred))
print('RMSE : ',(mean_squared_error(y_test,y_pred))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# r2 score train :  0.720005047226254
# MSE :  73.64364725702883
# RMSE :  8.581587688594041
# MAE :  6.721833014216682
# MAPE :  0.24623455173687744
#
# r2 score test :  0.7179665342052456
# MSE :  73.66535812030423
# RMSE :  8.582852563122836
# MAE :  6.690355643332342
# MAPE :  0.253258830067976

# %%
# xgboost

# train scores and errors
y_pred_xgb1=model_lr.predict(x_train)
print('r2 score train : ',r2_score(y_train,y_pred_xgb1))
print('MSE : ',mean_squared_error(y_train,y_pred_xgb1))
print('RMSE : ',(mean_squared_error(y_train,y_pred_xgb1))**0.5)
print('MAE : ',mean_absolute_error(y_train,y_pred_xgb1))
print('MAPE : ',mean_absolute_percentage_error(y_train,y_pred_xgb1))

# test scores and errors
y_pred_xgb=model_lr.predict(x_test)
print('\nr2 score test : ',r2_score(y_test,y_pred_xgb))
print('MSE : ',mean_squared_error(y_test,y_pred_xgb))
print('RMSE : ',(mean_squared_error(y_test,y_pred_xgb))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred_xgb))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred_xgb))
# Out:
# r2 score train :  0.720005047226254
# MSE :  73.64364725702883
# RMSE :  8.581587688594041
# MAE :  6.721833014216682
# MAPE :  0.24623455173687744
#
# r2 score test :  0.7179665342052456
# MSE :  73.66535812030423
# RMSE :  8.582852563122836
# MAE :  6.690355643332342
# MAPE :  0.253258830067976

# %% [markdown]
# # Regularization (Ridge ,LASSO and Elastic net)

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
model_ridge=Ridge(alpha=10)

# %%
model_ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
model_ridge.score(x_test,y_test)
# Out:
# 0.717961890928128

# %%
# LASSO 
model_lasso=Lasso(alpha=10)

# %%
model_lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
model_lasso.score(x_test,y_test)
# Out:
# 0.7167265434955663

# %%
# Elastic net 

model_en=ElasticNet(alpha=10,l1_ratio=0.2)

# %%
model_en.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=10, l1_ratio=0.2)

# %%
model_en.score(x_test,y_test)
# Out:
# 0.7145909837120712

# %%
pd.DataFrame({'LR':model_lr.coef_,
              'Ridge':model_ridge.coef_,
              'Lasso':model_lasso.coef_,
              'EN':model_en.coef_},index=x.columns)
# Out:
#                           LR     Ridge     Lasso        EN
# Cement              0.114089  0.114090  0.105597  0.112401
# Blast Furnace Slag  0.097726  0.097727  0.086403  0.095179
# Fly Ash             0.082427  0.082432  0.073318  0.082761
# Water              -0.191760 -0.191781 -0.230551 -0.218206
# Superplasticizer    0.171420  0.171270  0.000000  0.031030
# Coarse Aggregate    0.011690  0.011686 -0.000000  0.005692
# Fine Aggregate      0.016592  0.016592  0.005396  0.012946
# Age                 0.250238  0.250235  0.239630  0.246610

# %% [markdown]
# ### Hyper-parameter Tunning

# %%
# lets tune alpha parameter in Lasso

grid={'alpha':[0.1,1,5,10,20,50,100]}

# %%
gscv=GridSearchCV(estimator=model_lasso,param_grid=grid,scoring='r2',cv=5,verbose=3)

# %%
gscv.fit(x,y)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5] END .........................alpha=0.1;, score=0.569 total time=   0.0s
# [CV 2/5] END .........................alpha=0.1;, score=0.595 total time=   0.0s
# [CV 3/5] END .........................alpha=0.1;, score=0.640 total time=   0.0s
# [CV 4/5] END .........................alpha=0.1;, score=0.763 total time=   0.0s
# [CV 5/5] END .........................alpha=0.1;, score=0.511 total time=   0.0s
# [CV 1/5] END ...........................alpha=1;, score=0.593 total time=   0.0s
# [CV 2/5] END ...........................alpha=1;, score=0.590 total time=   0.0s
# [CV 3/5] END ...........................alpha=1;, score=0.635 total time=   0.0s
# [CV 4/5] END ...........................alpha=1;, score=0.760 total time=   0.0s
# [CV 5/5] END ...........................alpha=1;, score=0.516 total time=   0.0s
# [CV 1/5] END ...........................alpha=5;, score=0.660 total time=   0.0s
# [CV 2/5] END ...........................alpha=5;, score=0.577 total time=   0.0s
# [CV 3/5] END ...........................alpha=5;, score=0.630 total time=   0.0s
# [CV 4/5] END ...........................alpha=5;, score=0.751 total time=   0.0s
# [CV 5/5] END ...........................alpha=5;, score=0.524 total time=   0.0s
# [CV 1/5] END ..........................alpha=10;, score=0.675 total time=   0.0s
# [CV 2/5] END ..........................alpha=10;, score=0.565 total time=   0.0s
# [CV 3/5] END ..........................alpha=10;, score=0.626 total time=   0.0s
# [CV 4/5] END ..........................alpha=10;, score=0.743 total time=   0.0s
# [CV 5/5] END ..........................alpha=10;, score=0.534 total time=   0.0s
# [CV 1/5] END ..........................alpha=20;, score=0.680 total time=   0.0s
# [CV 2/5] END ..........................alpha=20;, score=0.537 total time=   0.0s
# [CV 3/5] END ..........................alpha=20;, score=0.614 total time=   0.0s
# [CV 4/5] END ..........................alpha=20;, score=0.718 total time=   0.0s
# [CV 5/5] END ..........................alpha=20;, score=0.542 total time=   0.0s
# [CV 1/5] END ..........................alpha=50;, score=0.617 total time=   0.0s
# [CV 2/5] END ..........................alpha=50;, score=0.425 total time=   0.0s
# [CV 3/5] END ..........................alpha=50;, score=0.548 total time=   0.0s
# [CV 4/5] END ..........................alpha=50;, score=0.595 total time=   0.0s
# [CV 5/5] END ..........................alpha=50;, score=0.544 total time=   0.0s
# [CV 1/5] END .........................alpha=100;, score=0.414 total time=   0.0s
# [CV 2/5] END .........................alpha=100;, score=0.242 total time=   0.0s
# [CV 3/5] END .........................alpha=100;, score=0.340 total time=   0.0s
# [CV 4/5] END .........................alpha=100;, score=0.230 total time=   0.0s
# [CV 5/5] END .........................alpha=100;, score=0.489 total time=   0.0s
# GridSearchCV(cv=5, estimator=Lasso(alpha=10),
#              param_grid={'alpha': [0.1, 1, 5, 10, 20, 50, 100]}, scoring='r2',
#              verbose=3)

# %%
gscv.best_score_
# Out:
# 0.6285395708330986

# %%
gscv.best_params_
# Out:
# {'alpha': 10}

# %%
gscv.best_score_
# Out:
# 0.6285395708330986

# %%
# grid for Elastic net


grid1={'alpha':[0.1,1,5,10,20,50,100],
      'l1_ratio':[0.01,0.05,0.10,0.15,0.20]}

# %%
gscv=GridSearchCV(estimator=ElasticNet(),param_grid=grid1,scoring='r2',cv=5,verbose=3)

# %%
gscv.fit(x,y)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# [CV 1/5] END ..........alpha=0.1, l1_ratio=0.01;, score=0.568 total time=   0.0s
# [CV 2/5] END ..........alpha=0.1, l1_ratio=0.01;, score=0.596 total time=   0.0s
# [CV 3/5] END ..........alpha=0.1, l1_ratio=0.01;, score=0.641 total time=   0.0s
# [CV 4/5] END ..........alpha=0.1, l1_ratio=0.01;, score=0.763 total time=   0.0s
# [CV 5/5] END ..........alpha=0.1, l1_ratio=0.01;, score=0.511 total time=   0.0s
# [CV 1/5] END ..........alpha=0.1, l1_ratio=0.05;, score=0.568 total time=   0.0s
# [CV 2/5] END ..........alpha=0.1, l1_ratio=0.05;, score=0.596 total time=   0.0s
# [CV 3/5] END ..........alpha=0.1, l1_ratio=0.05;, score=0.641 total time=   0.0s
# [CV 4/5] END ..........alpha=0.1, l1_ratio=0.05;, score=0.763 total time=   0.0s
# [CV 5/5] END ..........alpha=0.1, l1_ratio=0.05;, score=0.511 total time=   0.0s
# [CV 1/5] END ...........alpha=0.1, l1_ratio=0.1;, score=0.568 total time=   0.0s
# [CV 2/5] END ...........alpha=0.1, l1_ratio=0.1;, score=0.596 total time=   0.0s
# [CV 3/5] END ...........alpha=0.1, l1_ratio=0.1;, score=0.641 total time=   0.0s
# [CV 4/5] END ...........alpha=0.1, l1_ratio=0.1;, score=0.763 total time=   0.0s
# [CV 5/5] END ...........alpha=0.1, l1_ratio=0.1;, score=0.511 total time=   0.0s
# [CV 1/5] END ..........alpha=0.1, l1_ratio=0.15;, score=0.568 total time=   0.0s
# [CV 2/5] END ..........alpha=0.1, l1_ratio=0.15;, score=0.596 total time=   0.0s
# [CV 3/5] END ..........alpha=0.1, l1_ratio=0.15;, score=0.641 total time=   0.0s
# [CV 4/5] END ..........alpha=0.1, l1_ratio=0.15;, score=0.763 total time=   0.0s
# [CV 5/5] END ..........alpha=0.1, l1_ratio=0.15;, score=0.511 total time=   0.0s
# [CV 1/5] END ...........alpha=0.1, l1_ratio=0.2;, score=0.568 total time=   0.0s
# [CV 2/5] END ...........alpha=0.1, l1_ratio=0.2;, score=0.596 total time=   0.0s
# [CV 3/5] END ...........alpha=0.1, l1_ratio=0.2;, score=0.641 total time=   0.0s
# [CV 4/5] END ...........alpha=0.1, l1_ratio=0.2;, score=0.763 total time=   0.0s
# [CV 5/5] END ...........alpha=0.1, l1_ratio=0.2;, score=0.511 total time=   0.0s
# [CV 1/5] END ............alpha=1, l1_ratio=0.01;, score=0.579 total time=   0.0s
# [CV 2/5] END ............alpha=1, l1_ratio=0.01;, score=0.595 total time=   0.0s
# [CV 3/5] END ............alpha=1, l1_ratio=0.01;, score=0.640 total time=   0.0s
# [CV 4/5] END ............alpha=1, l1_ratio=0.01;, score=0.763 total time=   0.0s
# [CV 5/5] END ............alpha=1, l1_ratio=0.01;, score=0.512 total time=   0.0s
# [CV 1/5] END ............alpha=1, l1_ratio=0.05;, score=0.580 total time=   0.0s
# [CV 2/5] END ............alpha=1, l1_ratio=0.05;, score=0.595 total time=   0.0s
# [CV 3/5] END ............alpha=1, l1_ratio=0.05;, score=0.640 total time=   0.0s
# [CV 4/5] END ............alpha=1, l1_ratio=0.05;, score=0.763 total time=   0.0s
# [CV 5/5] END ............alpha=1, l1_ratio=0.05;, score=0.512 total time=   0.0s
# [CV 1/5] END .............alpha=1, l1_ratio=0.1;, score=0.581 total time=   0.0s
# [CV 2/5] END .............alpha=1, l1_ratio=0.1;, score=0.595 total time=   0.0s
# [CV 3/5] END .............alpha=1, l1_ratio=0.1;, score=0.640 total time=   0.0s
# [CV 4/5] END .............alpha=1, l1_ratio=0.1;, score=0.762 total time=   0.0s
# [CV 5/5] END .............alpha=1, l1_ratio=0.1;, score=0.513 total time=   0.0s
# [CV 1/5] END ............alpha=1, l1_ratio=0.15;, score=0.581 total time=   0.0s
# [CV 2/5] END ............alpha=1, l1_ratio=0.15;, score=0.594 total time=   0.0s
# [CV 3/5] END ............alpha=1, l1_ratio=0.15;, score=0.639 total time=   0.0s
# [CV 4/5] END ............alpha=1, l1_ratio=0.15;, score=0.762 total time=   0.0s
# [CV 5/5] END ............alpha=1, l1_ratio=0.15;, score=0.513 total time=   0.0s
# [CV 1/5] END .............alpha=1, l1_ratio=0.2;, score=0.582 total time=   0.0s
# [CV 2/5] END .............alpha=1, l1_ratio=0.2;, score=0.594 total time=   0.0s
# [CV 3/5] END .............alpha=1, l1_ratio=0.2;, score=0.639 total time=   0.0s
# [CV 4/5] END .............alpha=1, l1_ratio=0.2;, score=0.762 total time=   0.0s
# [CV 5/5] END .............alpha=1, l1_ratio=0.2;, score=0.513 total time=   0.0s
# [CV 1/5] END ............alpha=5, l1_ratio=0.01;, score=0.609 total time=   0.0s
# [CV 2/5] END ............alpha=5, l1_ratio=0.01;, score=0.592 total time=   0.0s
# [CV 3/5] END ............alpha=5, l1_ratio=0.01;, score=0.637 total time=   0.0s
# [CV 4/5] END ............alpha=5, l1_ratio=0.01;, score=0.760 total time=   0.0s
# [CV 5/5] END ............alpha=5, l1_ratio=0.01;, score=0.517 total time=   0.0s
# [CV 1/5] END ............alpha=5, l1_ratio=0.05;, score=0.612 total time=   0.0s
# [CV 2/5] END ............alpha=5, l1_ratio=0.05;, score=0.591 total time=   0.0s
# [CV 3/5] END ............alpha=5, l1_ratio=0.05;, score=0.637 total time=   0.0s
# [CV 4/5] END ............alpha=5, l1_ratio=0.05;, score=0.760 total time=   0.0s
# [CV 5/5] END ............alpha=5, l1_ratio=0.05;, score=0.518 total time=   0.0s
# [CV 1/5] END .............alpha=5, l1_ratio=0.1;, score=0.614 total time=   0.0s
# [CV 2/5] END .............alpha=5, l1_ratio=0.1;, score=0.590 total time=   0.0s
# [CV 3/5] END .............alpha=5, l1_ratio=0.1;, score=0.636 total time=   0.0s
# [CV 4/5] END .............alpha=5, l1_ratio=0.1;, score=0.759 total time=   0.0s
# [CV 5/5] END .............alpha=5, l1_ratio=0.1;, score=0.518 total time=   0.0s
# [CV 1/5] END ............alpha=5, l1_ratio=0.15;, score=0.617 total time=   0.0s
# [CV 2/5] END ............alpha=5, l1_ratio=0.15;, score=0.589 total time=   0.0s
# [CV 3/5] END ............alpha=5, l1_ratio=0.15;, score=0.635 total time=   0.0s
# [CV 4/5] END ............alpha=5, l1_ratio=0.15;, score=0.759 total time=   0.0s
# [CV 5/5] END ............alpha=5, l1_ratio=0.15;, score=0.519 total time=   0.0s
# [CV 1/5] END .............alpha=5, l1_ratio=0.2;, score=0.619 total time=   0.0s
# [CV 2/5] END .............alpha=5, l1_ratio=0.2;, score=0.588 total time=   0.0s
# [CV 3/5] END .............alpha=5, l1_ratio=0.2;, score=0.634 total time=   0.0s
# [CV 4/5] END .............alpha=5, l1_ratio=0.2;, score=0.758 total time=   0.0s
# [CV 5/5] END .............alpha=5, l1_ratio=0.2;, score=0.519 total time=   0.0s
# [CV 1/5] END ...........alpha=10, l1_ratio=0.01;, score=0.628 total time=   0.0s
# [CV 2/5] END ...........alpha=10, l1_ratio=0.01;, score=0.589 total time=   0.0s
# [CV 3/5] END ...........alpha=10, l1_ratio=0.01;, score=0.635 total time=   0.0s
# [CV 4/5] END ...........alpha=10, l1_ratio=0.01;, score=0.758 total time=   0.0s
# [CV 5/5] END ...........alpha=10, l1_ratio=0.01;, score=0.521 total time=   0.0s
# [CV 1/5] END ...........alpha=10, l1_ratio=0.05;, score=0.631 total time=   0.0s
# [CV 2/5] END ...........alpha=10, l1_ratio=0.05;, score=0.587 total time=   0.0s
# [CV 3/5] END ...........alpha=10, l1_ratio=0.05;, score=0.634 total time=   0.0s
# [CV 4/5] END ...........alpha=10, l1_ratio=0.05;, score=0.757 total time=   0.0s
# [CV 5/5] END ...........alpha=10, l1_ratio=0.05;, score=0.521 total time=   0.0s
# [CV 1/5] END ............alpha=10, l1_ratio=0.1;, score=0.635 total time=   0.0s
# [CV 2/5] END ............alpha=10, l1_ratio=0.1;, score=0.585 total time=   0.0s
# [CV 3/5] END ............alpha=10, l1_ratio=0.1;, score=0.633 total time=   0.0s
# [CV 4/5] END ............alpha=10, l1_ratio=0.1;, score=0.756 total time=   0.0s
# [CV 5/5] END ............alpha=10, l1_ratio=0.1;, score=0.522 total time=   0.0s
# [CV 1/5] END ...........alpha=10, l1_ratio=0.15;, score=0.639 total time=   0.0s
# [CV 2/5] END ...........alpha=10, l1_ratio=0.15;, score=0.583 total time=   0.0s
# [CV 3/5] END ...........alpha=10, l1_ratio=0.15;, score=0.631 total time=   0.0s
# [CV 4/5] END ...........alpha=10, l1_ratio=0.15;, score=0.755 total time=   0.0s
# [CV 5/5] END ...........alpha=10, l1_ratio=0.15;, score=0.523 total time=   0.0s
# [CV 1/5] END ............alpha=10, l1_ratio=0.2;, score=0.643 total time=   0.0s
# [CV 2/5] END ............alpha=10, l1_ratio=0.2;, score=0.581 total time=   0.0s
# [CV 3/5] END ............alpha=10, l1_ratio=0.2;, score=0.630 total time=   0.0s
# [CV 4/5] END ............alpha=10, l1_ratio=0.2;, score=0.754 total time=   0.0s
# [CV 5/5] END ............alpha=10, l1_ratio=0.2;, score=0.524 total time=   0.0s
# [CV 1/5] END ...........alpha=20, l1_ratio=0.01;, score=0.645 total time=   0.0s
# [CV 2/5] END ...........alpha=20, l1_ratio=0.01;, score=0.583 total time=   0.0s
# [CV 3/5] END ...........alpha=20, l1_ratio=0.01;, score=0.632 total time=   0.0s
# [CV 4/5] END ...........alpha=20, l1_ratio=0.01;, score=0.754 total time=   0.0s
# [CV 5/5] END ...........alpha=20, l1_ratio=0.01;, score=0.525 total time=   0.0s
# [CV 1/5] END ...........alpha=20, l1_ratio=0.05;, score=0.650 total time=   0.0s
# [CV 2/5] END ...........alpha=20, l1_ratio=0.05;, score=0.580 total time=   0.0s
# [CV 3/5] END ...........alpha=20, l1_ratio=0.05;, score=0.630 total time=   0.0s
# [CV 4/5] END ...........alpha=20, l1_ratio=0.05;, score=0.753 total time=   0.0s
# [CV 5/5] END ...........alpha=20, l1_ratio=0.05;, score=0.526 total time=   0.0s
# [CV 1/5] END ............alpha=20, l1_ratio=0.1;, score=0.655 total time=   0.0s
# [CV 2/5] END ............alpha=20, l1_ratio=0.1;, score=0.577 total time=   0.0s
# [CV 3/5] END ............alpha=20, l1_ratio=0.1;, score=0.628 total time=   0.0s
# [CV 4/5] END ............alpha=20, l1_ratio=0.1;, score=0.751 total time=   0.0s
# [CV 5/5] END ............alpha=20, l1_ratio=0.1;, score=0.527 total time=   0.0s
# [CV 1/5] END ...........alpha=20, l1_ratio=0.15;, score=0.660 total time=   0.0s
# [CV 2/5] END ...........alpha=20, l1_ratio=0.15;, score=0.574 total time=   0.0s
# [CV 3/5] END ...........alpha=20, l1_ratio=0.15;, score=0.627 total time=   0.0s
# [CV 4/5] END ...........alpha=20, l1_ratio=0.15;, score=0.748 total time=   0.0s
# [CV 5/5] END ...........alpha=20, l1_ratio=0.15;, score=0.528 total time=   0.0s
# [CV 1/5] END ............alpha=20, l1_ratio=0.2;, score=0.665 total time=   0.0s
# [CV 2/5] END ............alpha=20, l1_ratio=0.2;, score=0.571 total time=   0.0s
# [CV 3/5] END ............alpha=20, l1_ratio=0.2;, score=0.627 total time=   0.0s
# [CV 4/5] END ............alpha=20, l1_ratio=0.2;, score=0.746 total time=   0.0s
# [CV 5/5] END ............alpha=20, l1_ratio=0.2;, score=0.529 total time=   0.0s
# [CV 1/5] END ...........alpha=50, l1_ratio=0.01;, score=0.666 total time=   0.0s
# [CV 2/5] END ...........alpha=50, l1_ratio=0.01;, score=0.568 total time=   0.0s
# [CV 3/5] END ...........alpha=50, l1_ratio=0.01;, score=0.625 total time=   0.0s
# [CV 4/5] END ...........alpha=50, l1_ratio=0.01;, score=0.745 total time=   0.0s
# [CV 5/5] END ...........alpha=50, l1_ratio=0.01;, score=0.534 total time=   0.0s
# [CV 1/5] END ...........alpha=50, l1_ratio=0.05;, score=0.671 total time=   0.0s
# [CV 2/5] END ...........alpha=50, l1_ratio=0.05;, score=0.562 total time=   0.0s
# [CV 3/5] END ...........alpha=50, l1_ratio=0.05;, score=0.622 total time=   0.0s
# [CV 4/5] END ...........alpha=50, l1_ratio=0.05;, score=0.741 total time=   0.0s
# [CV 5/5] END ...........alpha=50, l1_ratio=0.05;, score=0.535 total time=   0.0s
# [CV 1/5] END ............alpha=50, l1_ratio=0.1;, score=0.676 total time=   0.0s
# [CV 2/5] END ............alpha=50, l1_ratio=0.1;, score=0.555 total time=   0.0s
# [CV 3/5] END ............alpha=50, l1_ratio=0.1;, score=0.620 total time=   0.0s
# [CV 4/5] END ............alpha=50, l1_ratio=0.1;, score=0.736 total time=   0.0s
# [CV 5/5] END ............alpha=50, l1_ratio=0.1;, score=0.536 total time=   0.0s
# [CV 1/5] END ...........alpha=50, l1_ratio=0.15;, score=0.680 total time=   0.0s
# [CV 2/5] END ...........alpha=50, l1_ratio=0.15;, score=0.550 total time=   0.0s
# [CV 3/5] END ...........alpha=50, l1_ratio=0.15;, score=0.619 total time=   0.0s
# [CV 4/5] END ...........alpha=50, l1_ratio=0.15;, score=0.733 total time=   0.0s
# [CV 5/5] END ...........alpha=50, l1_ratio=0.15;, score=0.538 total time=   0.0s
# [CV 1/5] END ............alpha=50, l1_ratio=0.2;, score=0.681 total time=   0.0s
# [CV 2/5] END ............alpha=50, l1_ratio=0.2;, score=0.545 total time=   0.0s
# [CV 3/5] END ............alpha=50, l1_ratio=0.2;, score=0.617 total time=   0.0s
# [CV 4/5] END ............alpha=50, l1_ratio=0.2;, score=0.730 total time=   0.0s
# [CV 5/5] END ............alpha=50, l1_ratio=0.2;, score=0.541 total time=   0.0s
# [CV 1/5] END ..........alpha=100, l1_ratio=0.01;, score=0.677 total time=   0.0s
# [CV 2/5] END ..........alpha=100, l1_ratio=0.01;, score=0.545 total time=   0.0s
# [CV 3/5] END ..........alpha=100, l1_ratio=0.01;, score=0.615 total time=   0.0s
# [CV 4/5] END ..........alpha=100, l1_ratio=0.01;, score=0.730 total time=   0.0s
# [CV 5/5] END ..........alpha=100, l1_ratio=0.01;, score=0.543 total time=   0.0s
# [CV 1/5] END ..........alpha=100, l1_ratio=0.05;, score=0.680 total time=   0.0s
# [CV 2/5] END ..........alpha=100, l1_ratio=0.05;, score=0.534 total time=   0.0s
# [CV 3/5] END ..........alpha=100, l1_ratio=0.05;, score=0.610 total time=   0.0s
# [CV 4/5] END ..........alpha=100, l1_ratio=0.05;, score=0.722 total time=   0.0s
# [CV 5/5] END ..........alpha=100, l1_ratio=0.05;, score=0.545 total time=   0.0s
# [CV 1/5] END ...........alpha=100, l1_ratio=0.1;, score=0.679 total time=   0.0s
# [CV 2/5] END ...........alpha=100, l1_ratio=0.1;, score=0.522 total time=   0.0s
# [CV 3/5] END ...........alpha=100, l1_ratio=0.1;, score=0.606 total time=   0.0s
# [CV 4/5] END ...........alpha=100, l1_ratio=0.1;, score=0.712 total time=   0.0s
# [CV 5/5] END ...........alpha=100, l1_ratio=0.1;, score=0.545 total time=   0.0s
# [CV 1/5] END ..........alpha=100, l1_ratio=0.15;, score=0.675 total time=   0.0s
# [CV 2/5] END ..........alpha=100, l1_ratio=0.15;, score=0.510 total time=   0.0s
# [CV 3/5] END ..........alpha=100, l1_ratio=0.15;, score=0.600 total time=   0.0s
# [CV 4/5] END ..........alpha=100, l1_ratio=0.15;, score=0.702 total time=   0.0s
# [CV 5/5] END ..........alpha=100, l1_ratio=0.15;, score=0.545 total time=   0.0s
# [CV 1/5] END ...........alpha=100, l1_ratio=0.2;, score=0.668 total time=   0.0s
# [CV 2/5] END ...........alpha=100, l1_ratio=0.2;, score=0.498 total time=   0.0s
# [CV 3/5] END ...........alpha=100, l1_ratio=0.2;, score=0.594 total time=   0.0s
# [CV 4/5] END ...........alpha=100, l1_ratio=0.2;, score=0.689 total time=   0.0s
# [CV 5/5] END ...........alpha=100, l1_ratio=0.2;, score=0.546 total time=   0.0s
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.1, 1, 5, 10, 20, 50, 100],
#                          'l1_ratio': [0.01, 0.05, 0.1, 0.15, 0.2]},
#              scoring='r2', verbose=3)

# %%
gscv.best_estimator_
# Out:
# ElasticNet(alpha=20, l1_ratio=0.01)

# %%
gscv.best_params_
# Out:
# {'alpha': 20, 'l1_ratio': 0.01}

# %%
gscv.best_score_
# Out:
# 0.6279115503067937

# %% [markdown]
# ### Gadient Descent

# %%
# we need to scale the data
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_train_s=pd.DataFrame(scaler.fit_transform(x_train),columns=x.columns)
x_test_s=pd.DataFrame(scaler.transform(x_test),columns=x.columns)
x_test_s
# Out:
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0    0.666490           -0.832144 -0.845930  0.480615         -1.034552
# 1    0.078560            1.363116 -0.845930  0.480615         -1.034552
# 2   -0.296366           -0.832144  0.701197 -1.109409          1.151342
# 3    1.880904           -0.832144  0.078429 -1.865245         -0.710083
# 4   -0.902609            0.586772 -0.845930  0.185037         -1.034552
# ..        ...                 ...       ...       ...               ...
# 196  2.121859           -0.832144 -0.845930  0.855953         -1.034552
# 197 -0.483540           -0.832144  1.005296  0.632158          0.012287
# 198 -1.714145            0.917204 -0.845930  0.480615         -1.034552
# 199  1.048163            0.278063 -0.845930 -1.119261          1.031801
# 200 -0.625992           -0.217014  1.063734 -1.225763          0.606576
#
#      Coarse Aggregate  Fine Aggregate       Age
# 0            1.046746        0.450586  1.428143
# 1           -0.569106       -0.676243 -0.874498
# 2            0.157506        1.439155  0.484893
# 3            1.594050       -1.625151 -0.291902
# 4            1.403797       -0.101709 -0.291902
# ..                ...             ...       ...
# 196          1.945889       -1.971107 -0.680299
# 197          0.683179       -0.184120 -0.985468
# 198         -1.155503        2.093877 -0.291902
# 199         -1.610287        1.892481  1.455886
# 200          0.503350        0.099440 -0.291902
#
# [201 rows x 8 columns]

# %%
model_sgd=SGDRegressor(penalty=None,learning_rate='constant',eta0=0.01)

# %%
model_sgd.fit(x_train_s,y_train)
# Out:
# SGDRegressor(learning_rate='constant', penalty=None)

# %%
model_sgd.intercept_
# Out:
# array([34.63261392])

# %%
model_sgd.coef_
# Out:
# array([10.90968792,  7.17917703,  5.83860622, -4.68240471,  0.79032986,
#         0.16813886,  1.9546593 ,  8.75140641])

# %%
model_sgd.score(x_test_s,y_test)
# Out:
# 0.6640858920462908

# %%
y_pred_sgd_train=model_sgd.predict(x_train_s)
y_pred_sgd_test=model_sgd.predict(x_test_s)

# %%
# xgboost

# train scores and errors
print('r2 score train : ',r2_score(y_train,y_pred_sgd_train))
print('MSE : ',mean_squared_error(y_train,y_pred_sgd_train))
print('RMSE : ',(mean_squared_error(y_train,y_pred_sgd_train))**0.5)
print('MAE : ',mean_absolute_error(y_train,y_pred_sgd_train))
print('MAPE : ',mean_absolute_percentage_error(y_train,y_pred_sgd_train))

# test scores and errors
print('\nr2 score test : ',r2_score(y_test,y_pred_sgd_test))
print('MSE : ',mean_squared_error(y_test,y_pred_sgd_test))
print('RMSE : ',(mean_squared_error(y_test,y_pred_sgd_test))**0.5)
print('MAE : ',mean_absolute_error(y_test,y_pred_sgd_test))
print('MAPE : ',mean_absolute_percentage_error(y_test,y_pred_sgd_test))
# Out:
# r2 score train :  0.6977877139186992
# MSE :  79.48720065284857
# RMSE :  8.915559469424707
# MAE :  6.926543359603779
# MAPE :  0.24974771919166208
#
# r2 score test :  0.6640858920462908
# MSE :  87.73864119402234
# RMSE :  9.36689068976586
# MAE :  7.39224197510849
# MAPE :  0.2716858203671423

# %% [markdown]
# ### Batch Gradient Descent

# %%
def batch_grad_desc(x,y,lr,iterat):
    X = np.array(x)
    const = np.ones(shape=(X.shape[0],1))
    X = np.concatenate([const,X],axis=1)
    Y = np.array(y)
    Y = Y.reshape(len(y),1)
    W = np.full(shape=(X.shape[1],1),fill_value=0)
    
    for i in range(iterat):
        ypred = X @ W
        dW = np.dot(X.T, ypred - Y)
        W = W - (lr * dW)
        
    return W

# %%
batch_grad_desc(x_train_s,y_train,lr=0.01,iterat=5)
# Out:
# array([[ 612820.56056688],
#        [ 339714.812726  ],
#        [-250621.70065692],
#        [ 216020.76522983],
#        [-675371.22295193],
#        [ 710791.37189605],
#        [-191546.37625314],
#        [ 383879.3110346 ],
#        [ -90008.3791995 ]])
